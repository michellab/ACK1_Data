# %%
# %pylab inline
import networkx as nx # does network analysis
matplotlib.rcParams.update({'font.size': 20})
#unimportant
import sys
import scipy.stats
sys.path.append('/home/jose/ack1/batch0001/analysis/ipython/pose1/wet') #adjust path to where you are working
import helper_scripts_analysis as helper
import seaborn as sns
sns.set_style("ticks")
sns.set_context("notebook", font_scale = 2)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/admin/miniconda3/lib/python2.7/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
#computational data

# %%
sim_data = ['mbar_ring_closure.csv']
comp_graph = nx.read_edgelist(
    sim_data[0], delimiter=',', create_using=nx.DiGraph(),nodetype=str, data=(('weight',float),('error',float)))
comp_graph = helper.symmetrize_graph(comp_graph)
for e in comp_graph.edges():
    print 'Free energy: %s %s %.2f' %(e[0], e[1],comp_graph.get_edge_data(e[0], e[1])['weight'])
pathaverage_comp = helper.get_average_paths(comp_graph, '2')
helper.get_cycles(comp_graph)
# Out:
# -0.9
# 0.8
# -1.8
# -1.4
# 1.6
# 0.2
# -0.72
# -2.55
# -1.8
# 0.3
# -0.6
# Free energy: 3 2 -1.60
# Free energy: 3 5 -0.90
# Free energy: 3 4 0.80
# Free energy: 3 7 -1.80
# Free energy: 3 6 -1.40
# Free energy: 2 3 1.60
# Free energy: 2 5 0.72
# Free energy: 2 6 0.20
# Free energy: 5 3 0.90
# Free energy: 5 2 -0.72
# Free energy: 5 6 -0.30
# Free energy: 4 3 -0.80
# Free energy: 4 7 -2.55
# Free energy: 4 6 -1.80
# Free energy: 7 3 1.80
# Free energy: 7 4 2.55
# Free energy: 7 6 0.60
# Free energy: 6 3 1.40
# Free energy: 6 2 -0.20
# Free energy: 6 5 0.30
# Free energy: 6 4 1.80
# Free energy: 6 7 -0.60
# DDG for path ['2', '3'] is 1.600000 +/- 0.100000 kcal/mol
# DDG for path ['2', '5', '3'] is 1.620000 +/- 0.072111 kcal/mol
# DDG for path ['2', '6', '3'] is 1.600000 +/- 0.223607 kcal/mol
# DDG for path ['2', '5', '6', '3'] is 1.820000 +/- 0.362767 kcal/mol
# DDG for path ['2', '6', '5', '3'] is 1.400000 +/- 0.321870 kcal/mol
# DDG for path ['2', '6', '4', '3'] is 1.200000 +/- 0.300000 kcal/mol
# DDG for path ['2', '6', '7', '3'] is 1.400000 +/- 0.244949 kcal/mol
# DDG for path ['2', '5', '6', '4', '3'] is 1.420000 +/- 0.414246 kcal/mol
# DDG for path ['2', '6', '4', '7', '3'] is 1.250000 +/- 0.257682 kcal/mol
# DDG for path ['2', '6', '7', '4', '3'] is 1.350000 +/- 0.310483 kcal/mol
# DDG for path ['2', '5', '6', '7', '3'] is 1.620000 +/- 0.376298 kcal/mol
# DDG for path ['2', '5', '6', '4', '7', '3'] is 1.470000 +/- 0.384708 kcal/mol
# DDG for path ['2', '5', '6', '7', '4', '3'] is 1.570000 +/- 0.421900 kcal/mol
# Average sum for path to 3 is 1.486154
# ================
# DDG for path ['2'] is 0.000000 +/- 0.000000 kcal/mol
# Average sum for path to 2 is 0.000000
# ================
# DDG for path ['2', '5'] is 0.720000 +/- 0.040000 kcal/mol
# DDG for path ['2', '3', '5'] is 0.700000 +/- 0.116619 kcal/mol
# DDG for path ['2', '6', '5'] is 0.500000 +/- 0.316228 kcal/mol
# DDG for path ['2', '3', '6', '5'] is 0.500000 +/- 0.374166 kcal/mol
# DDG for path ['2', '6', '3', '5'] is 0.700000 +/- 0.231517 kcal/mol
# DDG for path ['2', '3', '4', '6', '5'] is 0.900000 +/- 0.424264 kcal/mol
# DDG for path ['2', '6', '4', '3', '5'] is 0.300000 +/- 0.305941 kcal/mol
# DDG for path ['2', '3', '7', '6', '5'] is 0.700000 +/- 0.387298 kcal/mol
# DDG for path ['2', '6', '7', '3', '5'] is 0.500000 +/- 0.252190 kcal/mol
# DDG for path ['2', '3', '4', '7', '6', '5'] is 0.750000 +/- 0.431741 kcal/mol
# DDG for path ['2', '6', '4', '7', '3', '5'] is 0.350000 +/- 0.264575 kcal/mol
# DDG for path ['2', '3', '7', '4', '6', '5'] is 0.850000 +/- 0.395474 kcal/mol
# DDG for path ['2', '6', '7', '4', '3', '5'] is 0.450000 +/- 0.316228 kcal/mol
# Average sum for path to 5 is 0.609231
# ================
# DDG for path ['2', '3', '4'] is 2.400000 +/- 0.223607 kcal/mol
# DDG for path ['2', '6', '4'] is 2.000000 +/- 0.223607 kcal/mol
# DDG for path ['2', '3', '7', '4'] is 2.350000 +/- 0.162481 kcal/mol
# DDG for path ['2', '5', '3', '4'] is 2.420000 +/- 0.212603 kcal/mol
# DDG for path ['2', '6', '3', '4'] is 2.400000 +/- 0.300000 kcal/mol
# DDG for path ['2', '3', '6', '4'] is 2.000000 +/- 0.300000 kcal/mol
# DDG for path ['2', '5', '6', '4'] is 2.220000 +/- 0.362767 kcal/mol
# DDG for path ['2', '6', '7', '4'] is 2.150000 +/- 0.237487 kcal/mol
# DDG for path ['2', '3', '7', '6', '4'] is 2.200000 +/- 0.316228 kcal/mol
# DDG for path ['2', '5', '3', '7', '4'] is 2.370000 +/- 0.146969 kcal/mol
# DDG for path ['2', '6', '3', '7', '4'] is 2.350000 +/- 0.257682 kcal/mol
# DDG for path ['2', '3', '5', '6', '4'] is 2.200000 +/- 0.378946 kcal/mol
# DDG for path ['2', '3', '6', '7', '4'] is 2.150000 +/- 0.310483 kcal/mol
# DDG for path ['2', '5', '6', '3', '4'] is 2.620000 +/- 0.414246 kcal/mol
# DDG for path ['2', '6', '5', '3', '4'] is 2.200000 +/- 0.378946 kcal/mol
# DDG for path ['2', '6', '7', '3', '4'] is 2.200000 +/- 0.316228 kcal/mol
# DDG for path ['2', '5', '3', '6', '4'] is 2.020000 +/- 0.291890 kcal/mol
# DDG for path ['2', '5', '6', '7', '4'] is 2.370000 +/- 0.371484 kcal/mol
# DDG for path ['2', '5', '3', '7', '6', '4'] is 2.220000 +/- 0.308545 kcal/mol
# DDG for path ['2', '3', '5', '6', '7', '4'] is 2.350000 +/- 0.387298 kcal/mol
# DDG for path ['2', '5', '6', '3', '7', '4'] is 2.570000 +/- 0.384708 kcal/mol
# DDG for path ['2', '6', '5', '3', '7', '4'] is 2.150000 +/- 0.346410 kcal/mol
# DDG for path ['2', '5', '3', '6', '7', '4'] is 2.170000 +/- 0.302655 kcal/mol
# DDG for path ['2', '5', '6', '7', '3', '4'] is 2.420000 +/- 0.426146 kcal/mol
# Average sum for path to 4 is 2.270833
# ================
# DDG for path ['2', '3', '7'] is -0.200000 +/- 0.141421 kcal/mol
# DDG for path ['2', '6', '7'] is -0.400000 +/- 0.223607 kcal/mol
# DDG for path ['2', '3', '4', '7'] is -0.150000 +/- 0.237487 kcal/mol
# DDG for path ['2', '5', '3', '7'] is -0.180000 +/- 0.123288 kcal/mol
# DDG for path ['2', '6', '3', '7'] is -0.200000 +/- 0.244949 kcal/mol
# DDG for path ['2', '3', '6', '7'] is -0.400000 +/- 0.300000 kcal/mol
# DDG for path ['2', '5', '6', '7'] is -0.180000 +/- 0.362767 kcal/mol
# DDG for path ['2', '6', '4', '7'] is -0.550000 +/- 0.237487 kcal/mol
# DDG for path ['2', '3', '4', '6', '7'] is 0.000000 +/- 0.360555 kcal/mol
# DDG for path ['2', '5', '3', '4', '7'] is -0.130000 +/- 0.227156 kcal/mol
# DDG for path ['2', '6', '3', '4', '7'] is -0.150000 +/- 0.310483 kcal/mol
# DDG for path ['2', '3', '5', '6', '7'] is -0.200000 +/- 0.378946 kcal/mol
# DDG for path ['2', '3', '6', '4', '7'] is -0.550000 +/- 0.310483 kcal/mol
# DDG for path ['2', '5', '6', '3', '7'] is 0.020000 +/- 0.376298 kcal/mol
# DDG for path ['2', '6', '5', '3', '7'] is -0.400000 +/- 0.337046 kcal/mol
# DDG for path ['2', '6', '4', '3', '7'] is -0.600000 +/- 0.316228 kcal/mol
# DDG for path ['2', '5', '3', '6', '7'] is -0.380000 +/- 0.291890 kcal/mol
# DDG for path ['2', '5', '6', '4', '7'] is -0.330000 +/- 0.371484 kcal/mol
# DDG for path ['2', '5', '3', '4', '6', '7'] is 0.020000 +/- 0.353836 kcal/mol
# DDG for path ['2', '3', '5', '6', '4', '7'] is -0.350000 +/- 0.387298 kcal/mol
# DDG for path ['2', '5', '6', '3', '4', '7'] is 0.070000 +/- 0.421900 kcal/mol
# DDG for path ['2', '6', '5', '3', '4', '7'] is -0.350000 +/- 0.387298 kcal/mol
# DDG for path ['2', '5', '3', '6', '4', '7'] is -0.530000 +/- 0.302655 kcal/mol
# DDG for path ['2', '5', '6', '4', '3', '7'] is -0.380000 +/- 0.426146 kcal/mol
# Average sum for path to 7 is -0.270833
# ================
# DDG for path ['2', '6'] is 0.200000 +/- 0.100000 kcal/mol
# DDG for path ['2', '3', '6'] is 0.200000 +/- 0.223607 kcal/mol
# DDG for path ['2', '5', '6'] is 0.420000 +/- 0.302655 kcal/mol
# DDG for path ['2', '3', '5', '6'] is 0.400000 +/- 0.321870 kcal/mol
# DDG for path ['2', '5', '3', '6'] is 0.220000 +/- 0.212603 kcal/mol
# DDG for path ['2', '3', '4', '6'] is 0.600000 +/- 0.300000 kcal/mol
# DDG for path ['2', '3', '7', '6'] is 0.400000 +/- 0.244949 kcal/mol
# DDG for path ['2', '5', '3', '4', '6'] is 0.620000 +/- 0.291890 kcal/mol
# DDG for path ['2', '3', '4', '7', '6'] is 0.450000 +/- 0.310483 kcal/mol
# DDG for path ['2', '3', '7', '4', '6'] is 0.550000 +/- 0.257682 kcal/mol
# DDG for path ['2', '5', '3', '7', '6'] is 0.420000 +/- 0.234947 kcal/mol
# DDG for path ['2', '5', '3', '4', '7', '6'] is 0.470000 +/- 0.302655 kcal/mol
# DDG for path ['2', '5', '3', '7', '4', '6'] is 0.570000 +/- 0.248193 kcal/mol
# Average sum for path to 6 is 0.424615
# ================
# DDG for cycle ['3', '6', '7', '4'] is -0.25 ± 0.36 kcal/mol
# DDG for cycle ['3', '6', '7'] is -0.20 ± 0.30 kcal/mol
# DDG for cycle ['3', '6', '4', '7'] is -0.35 ± 0.31 kcal/mol
# DDG for cycle ['3', '6', '4'] is -0.40 ± 0.35 kcal/mol
# DDG for cycle ['3', '6', '5', '2'] is -0.22 ± 0.38 kcal/mol
# DDG for cycle ['3', '6', '5'] is -0.20 ± 0.37 kcal/mol
# DDG for cycle ['3', '6', '2', '5'] is 0.02 ± 0.23 kcal/mol
# DDG for cycle ['3', '6', '2'] is 0.00 ± 0.24 kcal/mol
# DDG for cycle ['3', '7', '6', '4'] is -0.20 ± 0.36 kcal/mol
# DDG for cycle ['3', '7', '6', '5', '2'] is -0.02 ± 0.39 kcal/mol
# DDG for cycle ['3', '7', '6', '5'] is -0.00 ± 0.38 kcal/mol
# DDG for cycle ['3', '7', '6', '2', '5'] is 0.22 ± 0.26 kcal/mol
# DDG for cycle ['3', '7', '6', '2'] is 0.20 ± 0.26 kcal/mol
# DDG for cycle ['3', '7', '6'] is 0.20 ± 0.30 kcal/mol
# DDG for cycle ['3', '7', '4', '6', '5', '2'] is 0.13 ± 0.40 kcal/mol
# DDG for cycle ['3', '7', '4', '6', '5'] is 0.15 ± 0.39 kcal/mol
# DDG for cycle ['3', '7', '4', '6', '2', '5'] is 0.37 ± 0.27 kcal/mol
# DDG for cycle ['3', '7', '4', '6', '2'] is 0.35 ± 0.28 kcal/mol
# DDG for cycle ['3', '7', '4', '6'] is 0.35 ± 0.31 kcal/mol
# DDG for cycle ['3', '7', '4'] is -0.05 ± 0.24 kcal/mol
# DDG for cycle ['3', '4', '6', '7'] is 0.20 ± 0.36 kcal/mol
# DDG for cycle ['3', '4', '6', '5', '2'] is 0.18 ± 0.43 kcal/mol
# DDG for cycle ['3', '4', '6', '5'] is 0.20 ± 0.42 kcal/mol
# DDG for cycle ['3', '4', '6', '2', '5'] is 0.42 ± 0.31 kcal/mol
# DDG for cycle ['3', '4', '6', '2'] is 0.40 ± 0.32 kcal/mol
# DDG for cycle ['3', '4', '6'] is 0.40 ± 0.35 kcal/mol
# DDG for cycle ['3', '4', '7', '6', '5', '2'] is 0.03 ± 0.43 kcal/mol
# DDG for cycle ['3', '4', '7', '6', '5'] is 0.05 ± 0.42 kcal/mol
# DDG for cycle ['3', '4', '7', '6', '2', '5'] is 0.27 ± 0.32 kcal/mol
# DDG for cycle ['3', '4', '7', '6', '2'] is 0.25 ± 0.33 kcal/mol
# DDG for cycle ['3', '4', '7', '6'] is 0.25 ± 0.36 kcal/mol
# DDG for cycle ['3', '4', '7'] is 0.05 ± 0.24 kcal/mol
# DDG for cycle ['3', '5', '6', '7', '4'] is -0.05 ± 0.42 kcal/mol
# DDG for cycle ['3', '5', '6', '7'] is 0.00 ± 0.38 kcal/mol
# DDG for cycle ['3', '5', '6', '4', '7'] is -0.15 ± 0.39 kcal/mol
# DDG for cycle ['3', '5', '6', '4'] is -0.20 ± 0.42 kcal/mol
# DDG for cycle ['3', '5', '6', '2'] is 0.20 ± 0.34 kcal/mol
# DDG for cycle ['3', '5', '6'] is 0.20 ± 0.37 kcal/mol
# DDG for cycle ['3', '5', '2', '6', '7', '4'] is -0.27 ± 0.32 kcal/mol
# DDG for cycle ['3', '5', '2', '6', '7'] is -0.22 ± 0.26 kcal/mol
# DDG for cycle ['3', '5', '2', '6', '4', '7'] is -0.37 ± 0.27 kcal/mol
# DDG for cycle ['3', '5', '2', '6', '4'] is -0.42 ± 0.31 kcal/mol
# DDG for cycle ['3', '5', '2', '6'] is -0.02 ± 0.23 kcal/mol
# DDG for cycle ['3', '5', '2'] is -0.02 ± 0.12 kcal/mol
# DDG for cycle ['3', '2', '6', '7', '4'] is -0.25 ± 0.33 kcal/mol
# DDG for cycle ['3', '2', '6', '7'] is -0.20 ± 0.26 kcal/mol
# DDG for cycle ['3', '2', '6', '4', '7'] is -0.35 ± 0.28 kcal/mol
# DDG for cycle ['3', '2', '6', '4'] is -0.40 ± 0.32 kcal/mol
# DDG for cycle ['3', '2', '6', '5'] is -0.20 ± 0.34 kcal/mol
# DDG for cycle ['3', '2', '6'] is -0.00 ± 0.24 kcal/mol
# DDG for cycle ['3', '2', '5', '6', '7', '4'] is -0.03 ± 0.43 kcal/mol
# DDG for cycle ['3', '2', '5', '6', '7'] is 0.02 ± 0.39 kcal/mol
# DDG for cycle ['3', '2', '5', '6', '4', '7'] is -0.13 ± 0.40 kcal/mol
# DDG for cycle ['3', '2', '5', '6', '4'] is -0.18 ± 0.43 kcal/mol
# DDG for cycle ['3', '2', '5', '6'] is 0.22 ± 0.38 kcal/mol
# DDG for cycle ['3', '2', '5'] is 0.02 ± 0.12 kcal/mol
# DDG for cycle ['2', '6', '5'] is -0.22 ± 0.32 kcal/mol
# DDG for cycle ['2', '5', '6'] is 0.22 ± 0.32 kcal/mol
# DDG for cycle ['4', '6', '7'] is 0.15 ± 0.29 kcal/mol
# DDG for cycle ['4', '7', '6'] is -0.15 ± 0.29 kcal/mol
