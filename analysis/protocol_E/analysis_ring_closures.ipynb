# %%
# %pylab inline
import networkx as nx # does network analysis
matplotlib.rcParams.update({'font.size': 20})
#unimportant
import sys
import scipy.stats
sys.path.append('/Volumes/Edimburgo/ack1/batch0001/analysis/ipython/best_poses/dry') #adjust path to where you are working
import helper_scripts_analysis as helper
import seaborn as sns
sns.set_style("ticks")
sns.set_context("notebook", font_scale = 2)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/admin/miniconda3/lib/python2.7/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
#computational data

# %%
sim_data = ['mbar_ring_closure.csv']
comp_graph = nx.read_edgelist(
    sim_data[0], delimiter=',', create_using=nx.DiGraph(),nodetype=str, data=(('weight',float),('error',float)))
comp_graph = helper.symmetrize_graph(comp_graph)
for e in comp_graph.edges():
    print 'Free energy: %s %s %.2f' %(e[0], e[1],comp_graph.get_edge_data(e[0], e[1])['weight'])
pathaverage_comp = helper.get_average_paths(comp_graph, '2')   
helper.get_cycles(comp_graph)
# Out:
# -0.89
# 1.1
# -0.7
# -1.14
# 1.0
# 0.0
# -0.57
# -1.31
# -2.1
# -0.1
# 0.6
# Free energy: 3 2 -1.00
# Free energy: 3 5 -0.89
# Free energy: 3 4 1.10
# Free energy: 3 7 -0.70
# Free energy: 3 6 -1.14
# Free energy: 2 3 1.00
# Free energy: 2 5 0.57
# Free energy: 2 6 0.00
# Free energy: 5 3 0.89
# Free energy: 5 2 -0.57
# Free energy: 5 6 0.10
# Free energy: 4 3 -1.10
# Free energy: 4 7 -1.31
# Free energy: 4 6 -2.10
# Free energy: 7 3 0.70
# Free energy: 7 4 1.31
# Free energy: 7 6 -0.60
# Free energy: 6 3 1.14
# Free energy: 6 2 -0.00
# Free energy: 6 5 -0.10
# Free energy: 6 4 2.10
# Free energy: 6 7 0.60
# DDG for path ['2', '3'] is 1.000000 +/- 0.300000 kcal/mol
# DDG for path ['2', '5', '3'] is 1.460000 +/- 0.086023 kcal/mol
# DDG for path ['2', '6', '3'] is 1.140000 +/- 0.805047 kcal/mol
# DDG for path ['2', '5', '6', '3'] is 1.810000 +/- 0.133791 kcal/mol
# DDG for path ['2', '6', '5', '3'] is 0.790000 +/- 0.804612 kcal/mol
# DDG for path ['2', '6', '4', '3'] is 1.000000 +/- 0.900000 kcal/mol
# DDG for path ['2', '6', '7', '3'] is 1.300000 +/- 1.174734 kcal/mol
# DDG for path ['2', '5', '6', '4', '3'] is 1.670000 +/- 0.424028 kcal/mol
# DDG for path ['2', '6', '4', '7', '3'] is 1.490000 +/- 1.026450 kcal/mol
# DDG for path ['2', '6', '7', '4', '3'] is 0.810000 +/- 1.069392 kcal/mol
# DDG for path ['2', '5', '6', '7', '3'] is 1.970000 +/- 0.865910 kcal/mol
# DDG for path ['2', '5', '6', '4', '7', '3'] is 2.160000 +/- 0.650692 kcal/mol
# DDG for path ['2', '5', '6', '7', '4', '3'] is 1.480000 +/- 0.716519 kcal/mol
# Average sum for path to 3 is 1.390769
# ================
# DDG for path ['2'] is 0.000000 +/- 0.000000 kcal/mol
# Average sum for path to 2 is 0.000000
# ================
# DDG for path ['2', '5'] is 0.570000 +/- 0.070000 kcal/mol
# DDG for path ['2', '3', '5'] is 0.110000 +/- 0.304138 kcal/mol
# DDG for path ['2', '6', '5'] is -0.100000 +/- 0.803057 kcal/mol
# DDG for path ['2', '3', '6', '5'] is -0.240000 +/- 0.320936 kcal/mol
# DDG for path ['2', '6', '3', '5'] is 0.250000 +/- 0.806598 kcal/mol
# DDG for path ['2', '3', '4', '6', '5'] is -0.100000 +/- 0.514684 kcal/mol
# DDG for path ['2', '6', '4', '3', '5'] is 0.110000 +/- 0.901388 kcal/mol
# DDG for path ['2', '3', '7', '6', '5'] is -0.400000 +/- 0.913729 kcal/mol
# DDG for path ['2', '6', '7', '3', '5'] is 0.410000 +/- 1.175798 kcal/mol
# DDG for path ['2', '3', '4', '7', '6', '5'] is 0.090000 +/- 0.773628 kcal/mol
# DDG for path ['2', '6', '4', '7', '3', '5'] is 0.600000 +/- 1.027667 kcal/mol
# DDG for path ['2', '3', '7', '4', '6', '5'] is -0.590000 +/- 0.713092 kcal/mol
# DDG for path ['2', '6', '7', '4', '3', '5'] is -0.080000 +/- 1.070561 kcal/mol
# Average sum for path to 5 is 0.048462
# ================
# DDG for path ['2', '3', '4'] is 2.100000 +/- 0.316228 kcal/mol
# DDG for path ['2', '6', '4'] is 2.100000 +/- 0.894427 kcal/mol
# DDG for path ['2', '3', '7', '4'] is 1.610000 +/- 0.586174 kcal/mol
# DDG for path ['2', '5', '3', '4'] is 2.560000 +/- 0.131909 kcal/mol
# DDG for path ['2', '6', '3', '4'] is 2.240000 +/- 0.811234 kcal/mol
# DDG for path ['2', '3', '6', '4'] is 1.960000 +/- 0.508035 kcal/mol
# DDG for path ['2', '5', '6', '4'] is 2.770000 +/- 0.412068 kcal/mol
# DDG for path ['2', '6', '7', '4'] is 1.910000 +/- 1.064707 kcal/mol
# DDG for path ['2', '3', '7', '6', '4'] is 1.800000 +/- 0.994987 kcal/mol
# DDG for path ['2', '5', '3', '7', '4'] is 2.070000 +/- 0.510882 kcal/mol
# DDG for path ['2', '6', '3', '7', '4'] is 1.750000 +/- 0.949579 kcal/mol
# DDG for path ['2', '3', '5', '6', '4'] is 2.310000 +/- 0.507346 kcal/mol
# DDG for path ['2', '3', '6', '7', '4'] is 1.770000 +/- 0.769220 kcal/mol
# DDG for path ['2', '5', '6', '3', '4'] is 2.910000 +/- 0.167033 kcal/mol
# DDG for path ['2', '6', '5', '3', '4'] is 1.890000 +/- 0.810802 kcal/mol
# DDG for path ['2', '6', '7', '3', '4'] is 2.400000 +/- 1.178983 kcal/mol
# DDG for path ['2', '5', '3', '6', '4'] is 2.420000 +/- 0.418927 kcal/mol
# DDG for path ['2', '5', '6', '7', '4'] is 2.580000 +/- 0.709507 kcal/mol
# DDG for path ['2', '5', '3', '7', '6', '4'] is 2.260000 +/- 0.952575 kcal/mol
# DDG for path ['2', '3', '5', '6', '7', '4'] is 2.120000 +/- 0.768765 kcal/mol
# DDG for path ['2', '5', '6', '3', '7', '4'] is 2.420000 +/- 0.521057 kcal/mol
# DDG for path ['2', '6', '5', '3', '7', '4'] is 1.400000 +/- 0.949210 kcal/mol
# DDG for path ['2', '5', '3', '6', '7', '4'] is 2.230000 +/- 0.713512 kcal/mol
# DDG for path ['2', '5', '6', '7', '3', '4'] is 3.070000 +/- 0.871665 kcal/mol
# Average sum for path to 4 is 2.193750
# ================
# DDG for path ['2', '3', '7'] is 0.300000 +/- 0.583095 kcal/mol
# DDG for path ['2', '6', '7'] is 0.600000 +/- 1.063015 kcal/mol
# DDG for path ['2', '3', '4', '7'] is 0.790000 +/- 0.321870 kcal/mol
# DDG for path ['2', '5', '3', '7'] is 0.760000 +/- 0.507346 kcal/mol
# DDG for path ['2', '6', '3', '7'] is 0.440000 +/- 0.947681 kcal/mol
# DDG for path ['2', '3', '6', '7'] is 0.460000 +/- 0.766877 kcal/mol
# DDG for path ['2', '5', '6', '7'] is 1.270000 +/- 0.706965 kcal/mol
# DDG for path ['2', '6', '4', '7'] is 0.790000 +/- 0.896437 kcal/mol
# DDG for path ['2', '3', '4', '6', '7'] is 0.600000 +/- 0.866025 kcal/mol
# DDG for path ['2', '5', '3', '4', '7'] is 1.250000 +/- 0.144914 kcal/mol
# DDG for path ['2', '6', '3', '4', '7'] is 0.930000 +/- 0.813449 kcal/mol
# DDG for path ['2', '3', '5', '6', '7'] is 0.810000 +/- 0.766420 kcal/mol
# DDG for path ['2', '3', '6', '4', '7'] is 0.650000 +/- 0.511566 kcal/mol
# DDG for path ['2', '5', '6', '3', '7'] is 1.110000 +/- 0.517591 kcal/mol
# DDG for path ['2', '6', '5', '3', '7'] is 0.090000 +/- 0.947312 kcal/mol
# DDG for path ['2', '6', '4', '3', '7'] is 0.300000 +/- 1.029563 kcal/mol
# DDG for path ['2', '5', '3', '6', '7'] is 0.920000 +/- 0.710985 kcal/mol
# DDG for path ['2', '5', '6', '4', '7'] is 1.460000 +/- 0.416413 kcal/mol
# DDG for path ['2', '5', '3', '4', '6', '7'] is 1.060000 +/- 0.816946 kcal/mol
# DDG for path ['2', '3', '5', '6', '4', '7'] is 1.000000 +/- 0.510882 kcal/mol
# DDG for path ['2', '5', '6', '3', '4', '7'] is 1.600000 +/- 0.177482 kcal/mol
# DDG for path ['2', '6', '5', '3', '4', '7'] is 0.580000 +/- 0.813019 kcal/mol
# DDG for path ['2', '5', '3', '6', '4', '7'] is 1.110000 +/- 0.423202 kcal/mol
# DDG for path ['2', '5', '6', '4', '3', '7'] is 0.970000 +/- 0.655591 kcal/mol
# Average sum for path to 7 is 0.827083
# ================
# DDG for path ['2', '6'] is 0.000000 +/- 0.800000 kcal/mol
# DDG for path ['2', '3', '6'] is -0.140000 +/- 0.313209 kcal/mol
# DDG for path ['2', '5', '6'] is 0.670000 +/- 0.098995 kcal/mol
# DDG for path ['2', '3', '5', '6'] is 0.210000 +/- 0.312090 kcal/mol
# DDG for path ['2', '5', '3', '6'] is 0.320000 +/- 0.124499 kcal/mol
# DDG for path ['2', '3', '4', '6'] is 0.000000 +/- 0.509902 kcal/mol
# DDG for path ['2', '3', '7', '6'] is -0.300000 +/- 0.911043 kcal/mol
# DDG for path ['2', '5', '3', '4', '6'] is 0.460000 +/- 0.421189 kcal/mol
# DDG for path ['2', '3', '4', '7', '6'] is 0.190000 +/- 0.770454 kcal/mol
# DDG for path ['2', '3', '7', '4', '6'] is -0.490000 +/- 0.709648 kcal/mol
# DDG for path ['2', '5', '3', '7', '6'] is 0.160000 +/- 0.864523 kcal/mol
# DDG for path ['2', '5', '3', '4', '7', '6'] is 0.650000 +/- 0.714843 kcal/mol
# DDG for path ['2', '5', '3', '7', '4', '6'] is -0.030000 +/- 0.648845 kcal/mol
# Average sum for path to 6 is 0.130769
# ================
# DDG for cycle ['3', '6', '7', '4'] is -0.33 ± 0.72 kcal/mol
# DDG for cycle ['3', '6', '7'] is 0.16 ± 0.86 kcal/mol
# DDG for cycle ['3', '6', '4', '7'] is 0.35 ± 0.65 kcal/mol
# DDG for cycle ['3', '6', '4'] is -0.14 ± 0.42 kcal/mol
# DDG for cycle ['3', '6', '5', '2'] is -0.81 ± 0.33 kcal/mol
# DDG for cycle ['3', '6', '5'] is -0.35 ± 0.12 kcal/mol
# DDG for cycle ['3', '6', '2', '5'] is 0.32 ± 0.81 kcal/mol
# DDG for cycle ['3', '6', '2'] is -0.14 ± 0.86 kcal/mol
# DDG for cycle ['3', '7', '6', '4'] is -0.30 ± 0.95 kcal/mol
# DDG for cycle ['3', '7', '6', '5', '2'] is -0.97 ± 0.92 kcal/mol
# DDG for cycle ['3', '7', '6', '5'] is -0.51 ± 0.86 kcal/mol
# DDG for cycle ['3', '7', '6', '2', '5'] is 0.16 ± 1.18 kcal/mol
# DDG for cycle ['3', '7', '6', '2'] is -0.30 ± 1.21 kcal/mol
# DDG for cycle ['3', '7', '6'] is -0.16 ± 0.86 kcal/mol
# DDG for cycle ['3', '7', '4', '6', '5', '2'] is -1.16 ± 0.72 kcal/mol
# DDG for cycle ['3', '7', '4', '6', '5'] is -0.70 ± 0.65 kcal/mol
# DDG for cycle ['3', '7', '4', '6', '2', '5'] is -0.03 ± 1.03 kcal/mol
# DDG for cycle ['3', '7', '4', '6', '2'] is -0.49 ± 1.07 kcal/mol
# DDG for cycle ['3', '7', '4', '6'] is -0.35 ± 0.65 kcal/mol
# DDG for cycle ['3', '7', '4'] is -0.49 ± 0.51 kcal/mol
# DDG for cycle ['3', '4', '6', '7'] is 0.30 ± 0.95 kcal/mol
# DDG for cycle ['3', '4', '6', '5', '2'] is -0.67 ± 0.52 kcal/mol
# DDG for cycle ['3', '4', '6', '5'] is -0.21 ± 0.42 kcal/mol
# DDG for cycle ['3', '4', '6', '2', '5'] is 0.46 ± 0.90 kcal/mol
# DDG for cycle ['3', '4', '6', '2'] is 0.00 ± 0.95 kcal/mol
# DDG for cycle ['3', '4', '6'] is 0.14 ± 0.42 kcal/mol
# DDG for cycle ['3', '4', '7', '6', '5', '2'] is -0.48 ± 0.78 kcal/mol
# DDG for cycle ['3', '4', '7', '6', '5'] is -0.02 ± 0.71 kcal/mol
# DDG for cycle ['3', '4', '7', '6', '2', '5'] is 0.65 ± 1.07 kcal/mol
# DDG for cycle ['3', '4', '7', '6', '2'] is 0.19 ± 1.11 kcal/mol
# DDG for cycle ['3', '4', '7', '6'] is 0.33 ± 0.72 kcal/mol
# DDG for cycle ['3', '4', '7'] is 0.49 ± 0.51 kcal/mol
# DDG for cycle ['3', '5', '6', '7', '4'] is 0.02 ± 0.71 kcal/mol
# DDG for cycle ['3', '5', '6', '7'] is 0.51 ± 0.86 kcal/mol
# DDG for cycle ['3', '5', '6', '4', '7'] is 0.70 ± 0.65 kcal/mol
# DDG for cycle ['3', '5', '6', '4'] is 0.21 ± 0.42 kcal/mol
# DDG for cycle ['3', '5', '6', '2'] is 0.21 ± 0.86 kcal/mol
# DDG for cycle ['3', '5', '6'] is 0.35 ± 0.12 kcal/mol
# DDG for cycle ['3', '5', '2', '6', '7', '4'] is -0.65 ± 1.07 kcal/mol
# DDG for cycle ['3', '5', '2', '6', '7'] is -0.16 ± 1.18 kcal/mol
# DDG for cycle ['3', '5', '2', '6', '4', '7'] is 0.03 ± 1.03 kcal/mol
# DDG for cycle ['3', '5', '2', '6', '4'] is -0.46 ± 0.90 kcal/mol
# DDG for cycle ['3', '5', '2', '6'] is -0.32 ± 0.81 kcal/mol
# DDG for cycle ['3', '5', '2'] is -0.46 ± 0.31 kcal/mol
# DDG for cycle ['3', '2', '6', '7', '4'] is -0.19 ± 1.11 kcal/mol
# DDG for cycle ['3', '2', '6', '7'] is 0.30 ± 1.21 kcal/mol
# DDG for cycle ['3', '2', '6', '4', '7'] is 0.49 ± 1.07 kcal/mol
# DDG for cycle ['3', '2', '6', '4'] is 0.00 ± 0.95 kcal/mol
# DDG for cycle ['3', '2', '6', '5'] is -0.21 ± 0.86 kcal/mol
# DDG for cycle ['3', '2', '6'] is 0.14 ± 0.86 kcal/mol
# DDG for cycle ['3', '2', '5', '6', '7', '4'] is 0.48 ± 0.78 kcal/mol
# DDG for cycle ['3', '2', '5', '6', '7'] is 0.97 ± 0.92 kcal/mol
# DDG for cycle ['3', '2', '5', '6', '4', '7'] is 1.16 ± 0.72 kcal/mol
# DDG for cycle ['3', '2', '5', '6', '4'] is 0.67 ± 0.52 kcal/mol
# DDG for cycle ['3', '2', '5', '6'] is 0.81 ± 0.33 kcal/mol
# DDG for cycle ['3', '2', '5'] is 0.46 ± 0.31 kcal/mol
# DDG for cycle ['2', '6', '5'] is -0.67 ± 0.81 kcal/mol
# DDG for cycle ['2', '5', '6'] is 0.67 ± 0.81 kcal/mol
# DDG for cycle ['4', '6', '7'] is -0.19 ± 0.81 kcal/mol
# DDG for cycle ['4', '7', '6'] is 0.19 ± 0.81 kcal/mol
