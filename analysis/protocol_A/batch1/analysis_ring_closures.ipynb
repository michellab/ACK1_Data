# %%
# %pylab inline
import networkx as nx # does network analysis
matplotlib.rcParams.update({'font.size': 20})
#unimportant
import sys
import scipy.stats
sys.path.append('/Volumes/Edimburgo/ack1/batch0001/analysis/ipython/best_poses/dry') #adjust path to where you are working
import helper_scripts_analysis as helper
import seaborn as sns
sns.set_style("ticks")
sns.set_context("notebook", font_scale = 2)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/admin/miniconda3/lib/python2.7/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
#computational data

# %%
sim_data = ['mbar_ring_closure.csv']
comp_graph = nx.read_edgelist(
    sim_data[0], delimiter=',', create_using=nx.DiGraph(),nodetype=str, data=(('weight',float),('error',float)))
comp_graph = helper.symmetrize_graph(comp_graph)
for e in comp_graph.edges():
    print 'Free energy: %s %s %.2f' %(e[0], e[1],comp_graph.get_edge_data(e[0], e[1])['weight'])
pathaverage_comp = helper.get_average_paths(comp_graph, '2')   
helper.get_cycles(comp_graph)
# Out:
# -0.9
# 1.37
# -0.6
# -1.9
# 1.3
# -0.8
# -0.63
# -1.2
# -1.4
# 0.6
# 1.1
# Free energy: 3 2 -1.30
# Free energy: 3 5 -0.90
# Free energy: 3 4 1.37
# Free energy: 3 7 -0.60
# Free energy: 3 6 -1.90
# Free energy: 2 3 1.30
# Free energy: 2 5 0.63
# Free energy: 2 6 -0.80
# Free energy: 5 3 0.90
# Free energy: 5 2 -0.63
# Free energy: 5 6 -0.60
# Free energy: 4 3 -1.37
# Free energy: 4 7 -1.20
# Free energy: 4 6 -1.40
# Free energy: 7 3 0.60
# Free energy: 7 4 1.20
# Free energy: 7 6 -1.10
# Free energy: 6 3 1.90
# Free energy: 6 2 0.80
# Free energy: 6 5 0.60
# Free energy: 6 4 1.40
# Free energy: 6 7 1.10
# DDG for path ['2', '3'] is 1.300000 +/- 0.200000 kcal/mol
# DDG for path ['2', '5', '3'] is 1.530000 +/- 0.067082 kcal/mol
# DDG for path ['2', '6', '3'] is 1.100000 +/- 0.316228 kcal/mol
# DDG for path ['2', '5', '6', '3'] is 1.930000 +/- 0.225610 kcal/mol
# DDG for path ['2', '6', '5', '3'] is 0.700000 +/- 0.365513 kcal/mol
# DDG for path ['2', '6', '4', '3'] is -0.770000 +/- 0.503587 kcal/mol
# DDG for path ['2', '6', '7', '3'] is 0.900000 +/- 0.519615 kcal/mol
# DDG for path ['2', '5', '6', '4', '3'] is 0.060000 +/- 0.452217 kcal/mol
# DDG for path ['2', '6', '4', '7', '3'] is -0.000000 +/- 0.655744 kcal/mol
# DDG for path ['2', '6', '7', '4', '3'] is 0.130000 +/- 0.523068 kcal/mol
# DDG for path ['2', '5', '6', '7', '3'] is 1.730000 +/- 0.470000 kcal/mol
# DDG for path ['2', '5', '6', '4', '7', '3'] is 0.830000 +/- 0.617171 kcal/mol
# DDG for path ['2', '5', '6', '7', '4', '3'] is 0.960000 +/- 0.473814 kcal/mol
# Average sum for path to 3 is 0.800000
# ================
# DDG for path ['2'] is 0.000000 +/- 0.000000 kcal/mol
# Average sum for path to 2 is 0.000000
# ================
# DDG for path ['2', '5'] is 0.630000 +/- 0.030000 kcal/mol
# DDG for path ['2', '3', '5'] is 0.400000 +/- 0.208806 kcal/mol
# DDG for path ['2', '6', '5'] is -0.200000 +/- 0.360555 kcal/mol
# DDG for path ['2', '3', '6', '5'] is 0.000000 +/- 0.300000 kcal/mol
# DDG for path ['2', '6', '3', '5'] is 0.200000 +/- 0.321870 kcal/mol
# DDG for path ['2', '3', '4', '6', '5'] is 1.870000 +/- 0.493559 kcal/mol
# DDG for path ['2', '6', '4', '3', '5'] is -1.670000 +/- 0.507149 kcal/mol
# DDG for path ['2', '3', '7', '6', '5'] is 0.200000 +/- 0.509902 kcal/mol
# DDG for path ['2', '6', '7', '3', '5'] is 0.000000 +/- 0.523068 kcal/mol
# DDG for path ['2', '3', '4', '7', '6', '5'] is 0.970000 +/- 0.513420 kcal/mol
# DDG for path ['2', '6', '4', '7', '3', '5'] is -0.900000 +/- 0.658483 kcal/mol
# DDG for path ['2', '3', '7', '4', '6', '5'] is 1.100000 +/- 0.648074 kcal/mol
# DDG for path ['2', '6', '7', '4', '3', '5'] is -0.770000 +/- 0.526498 kcal/mol
# Average sum for path to 5 is 0.140769
# ================
# DDG for path ['2', '3', '4'] is 2.670000 +/- 0.208806 kcal/mol
# DDG for path ['2', '6', '4'] is 0.600000 +/- 0.500000 kcal/mol
# DDG for path ['2', '3', '7', '4'] is 1.900000 +/- 0.469042 kcal/mol
# DDG for path ['2', '5', '3', '4'] is 2.900000 +/- 0.090000 kcal/mol
# DDG for path ['2', '6', '3', '4'] is 2.470000 +/- 0.321870 kcal/mol
# DDG for path ['2', '3', '6', '4'] is 0.800000 +/- 0.458258 kcal/mol
# DDG for path ['2', '5', '6', '4'] is 1.430000 +/- 0.448219 kcal/mol
# DDG for path ['2', '6', '7', '4'] is 1.500000 +/- 0.519615 kcal/mol
# DDG for path ['2', '3', '7', '6', '4'] is 1.000000 +/- 0.616441 kcal/mol
# DDG for path ['2', '5', '3', '7', '4'] is 2.130000 +/- 0.429535 kcal/mol
# DDG for path ['2', '6', '3', '7', '4'] is 1.700000 +/- 0.529150 kcal/mol
# DDG for path ['2', '3', '5', '6', '4'] is 1.200000 +/- 0.493559 kcal/mol
# DDG for path ['2', '3', '6', '7', '4'] is 1.700000 +/- 0.479583 kcal/mol
# DDG for path ['2', '5', '6', '3', '4'] is 3.300000 +/- 0.233452 kcal/mol
# DDG for path ['2', '6', '5', '3', '4'] is 2.070000 +/- 0.370405 kcal/mol
# DDG for path ['2', '6', '7', '3', '4'] is 2.270000 +/- 0.523068 kcal/mol
# DDG for path ['2', '5', '3', '6', '4'] is 1.030000 +/- 0.417732 kcal/mol
# DDG for path ['2', '5', '6', '7', '4'] is 2.330000 +/- 0.470000 kcal/mol
# DDG for path ['2', '5', '3', '7', '6', '4'] is 1.230000 +/- 0.586941 kcal/mol
# DDG for path ['2', '3', '5', '6', '7', '4'] is 2.100000 +/- 0.513420 kcal/mol
# DDG for path ['2', '5', '6', '3', '7', '4'] is 2.530000 +/- 0.480521 kcal/mol
# DDG for path ['2', '6', '5', '3', '7', '4'] is 1.300000 +/- 0.560000 kcal/mol
# DDG for path ['2', '5', '3', '6', '7', '4'] is 1.930000 +/- 0.441022 kcal/mol
# DDG for path ['2', '5', '6', '7', '3', '4'] is 3.100000 +/- 0.473814 kcal/mol
# Average sum for path to 4 is 1.882917
# ================
# DDG for path ['2', '3', '7'] is 0.700000 +/- 0.360555 kcal/mol
# DDG for path ['2', '6', '7'] is 0.300000 +/- 0.424264 kcal/mol
# DDG for path ['2', '3', '4', '7'] is 1.470000 +/- 0.365513 kcal/mol
# DDG for path ['2', '5', '3', '7'] is 0.930000 +/- 0.307409 kcal/mol
# DDG for path ['2', '6', '3', '7'] is 0.500000 +/- 0.435890 kcal/mol
# DDG for path ['2', '3', '6', '7'] is 0.500000 +/- 0.374166 kcal/mol
# DDG for path ['2', '5', '6', '7'] is 1.130000 +/- 0.361801 kcal/mol
# DDG for path ['2', '6', '4', '7'] is -0.600000 +/- 0.583095 kcal/mol
# DDG for path ['2', '3', '4', '6', '7'] is 2.370000 +/- 0.541849 kcal/mol
# DDG for path ['2', '5', '3', '4', '7'] is 1.700000 +/- 0.313209 kcal/mol
# DDG for path ['2', '6', '3', '4', '7'] is 1.270000 +/- 0.440000 kcal/mol
# DDG for path ['2', '3', '5', '6', '7'] is 0.900000 +/- 0.416653 kcal/mol
# DDG for path ['2', '3', '6', '4', '7'] is -0.400000 +/- 0.547723 kcal/mol
# DDG for path ['2', '5', '6', '3', '7'] is 1.330000 +/- 0.375366 kcal/mol
# DDG for path ['2', '6', '5', '3', '7'] is 0.100000 +/- 0.472864 kcal/mol
# DDG for path ['2', '6', '4', '3', '7'] is -1.370000 +/- 0.586174 kcal/mol
# DDG for path ['2', '5', '3', '6', '7'] is 0.730000 +/- 0.323265 kcal/mol
# DDG for path ['2', '5', '6', '4', '7'] is 0.230000 +/- 0.539351 kcal/mol
# DDG for path ['2', '5', '3', '4', '6', '7'] is 2.600000 +/- 0.508035 kcal/mol
# DDG for path ['2', '3', '5', '6', '4', '7'] is 0.000000 +/- 0.577581 kcal/mol
# DDG for path ['2', '5', '6', '3', '4', '7'] is 2.100000 +/- 0.380132 kcal/mol
# DDG for path ['2', '6', '5', '3', '4', '7'] is 0.870000 +/- 0.476655 kcal/mol
# DDG for path ['2', '5', '3', '6', '4', '7'] is -0.170000 +/- 0.514296 kcal/mol
# DDG for path ['2', '5', '6', '4', '3', '7'] is -0.540000 +/- 0.542679 kcal/mol
# Average sum for path to 7 is 0.693750
# ================
# DDG for path ['2', '6'] is -0.800000 +/- 0.300000 kcal/mol
# DDG for path ['2', '3', '6'] is -0.600000 +/- 0.223607 kcal/mol
# DDG for path ['2', '5', '6'] is 0.030000 +/- 0.202237 kcal/mol
# DDG for path ['2', '3', '5', '6'] is -0.200000 +/- 0.289137 kcal/mol
# DDG for path ['2', '5', '3', '6'] is -0.370000 +/- 0.120416 kcal/mol
# DDG for path ['2', '3', '4', '6'] is 1.270000 +/- 0.451221 kcal/mol
# DDG for path ['2', '3', '7', '6'] is -0.400000 +/- 0.469042 kcal/mol
# DDG for path ['2', '5', '3', '4', '6'] is 1.500000 +/- 0.410000 kcal/mol
# DDG for path ['2', '3', '4', '7', '6'] is 0.370000 +/- 0.472864 kcal/mol
# DDG for path ['2', '3', '7', '4', '6'] is 0.500000 +/- 0.616441 kcal/mol
# DDG for path ['2', '5', '3', '7', '6'] is -0.170000 +/- 0.429535 kcal/mol
# DDG for path ['2', '5', '3', '4', '7', '6'] is 0.600000 +/- 0.433705 kcal/mol
# DDG for path ['2', '5', '3', '7', '4', '6'] is 0.730000 +/- 0.586941 kcal/mol
# Average sum for path to 6 is 0.189231
# ================
# DDG for cycle ['3', '6', '7', '4'] is -0.97 ± 0.44 kcal/mol
# DDG for cycle ['3', '6', '7'] is -0.20 ± 0.44 kcal/mol
# DDG for cycle ['3', '6', '4', '7'] is -1.10 ± 0.59 kcal/mol
# DDG for cycle ['3', '6', '4'] is -1.87 ± 0.42 kcal/mol
# DDG for cycle ['3', '6', '5', '2'] is -0.63 ± 0.30 kcal/mol
# DDG for cycle ['3', '6', '5'] is -0.40 ± 0.23 kcal/mol
# DDG for cycle ['3', '6', '2', '5'] is 0.43 ± 0.32 kcal/mol
# DDG for cycle ['3', '6', '2'] is 0.20 ± 0.37 kcal/mol
# DDG for cycle ['3', '7', '6', '4'] is -1.67 ± 0.59 kcal/mol
# DDG for cycle ['3', '7', '6', '5', '2'] is -0.43 ± 0.51 kcal/mol
# DDG for cycle ['3', '7', '6', '5'] is -0.20 ± 0.47 kcal/mol
# DDG for cycle ['3', '7', '6', '2', '5'] is 0.63 ± 0.52 kcal/mol
# DDG for cycle ['3', '7', '6', '2'] is 0.40 ± 0.56 kcal/mol
# DDG for cycle ['3', '7', '6'] is 0.20 ± 0.44 kcal/mol
# DDG for cycle ['3', '7', '4', '6', '5', '2'] is 0.47 ± 0.65 kcal/mol
# DDG for cycle ['3', '7', '4', '6', '5'] is 0.70 ± 0.62 kcal/mol
# DDG for cycle ['3', '7', '4', '6', '2', '5'] is 1.53 ± 0.66 kcal/mol
# DDG for cycle ['3', '7', '4', '6', '2'] is 1.30 ± 0.69 kcal/mol
# DDG for cycle ['3', '7', '4', '6'] is 1.10 ± 0.59 kcal/mol
# DDG for cycle ['3', '7', '4'] is -0.77 ± 0.43 kcal/mol
# DDG for cycle ['3', '4', '6', '7'] is 1.67 ± 0.59 kcal/mol
# DDG for cycle ['3', '4', '6', '5', '2'] is 1.24 ± 0.49 kcal/mol
# DDG for cycle ['3', '4', '6', '5'] is 1.47 ± 0.46 kcal/mol
# DDG for cycle ['3', '4', '6', '2', '5'] is 2.30 ± 0.51 kcal/mol
# DDG for cycle ['3', '4', '6', '2'] is 2.07 ± 0.54 kcal/mol
# DDG for cycle ['3', '4', '6'] is 1.87 ± 0.42 kcal/mol
# DDG for cycle ['3', '4', '7', '6', '5', '2'] is 0.34 ± 0.51 kcal/mol
# DDG for cycle ['3', '4', '7', '6', '5'] is 0.57 ± 0.48 kcal/mol
# DDG for cycle ['3', '4', '7', '6', '2', '5'] is 1.40 ± 0.53 kcal/mol
# DDG for cycle ['3', '4', '7', '6', '2'] is 1.17 ± 0.56 kcal/mol
# DDG for cycle ['3', '4', '7', '6'] is 0.97 ± 0.44 kcal/mol
# DDG for cycle ['3', '4', '7'] is 0.77 ± 0.43 kcal/mol
# DDG for cycle ['3', '5', '6', '7', '4'] is -0.57 ± 0.48 kcal/mol
# DDG for cycle ['3', '5', '6', '7'] is 0.20 ± 0.47 kcal/mol
# DDG for cycle ['3', '5', '6', '4', '7'] is -0.70 ± 0.62 kcal/mol
# DDG for cycle ['3', '5', '6', '4'] is -1.47 ± 0.46 kcal/mol
# DDG for cycle ['3', '5', '6', '2'] is 0.60 ± 0.42 kcal/mol
# DDG for cycle ['3', '5', '6'] is 0.40 ± 0.23 kcal/mol
# DDG for cycle ['3', '5', '2', '6', '7', '4'] is -1.40 ± 0.53 kcal/mol
# DDG for cycle ['3', '5', '2', '6', '7'] is -0.63 ± 0.52 kcal/mol
# DDG for cycle ['3', '5', '2', '6', '4', '7'] is -1.53 ± 0.66 kcal/mol
# DDG for cycle ['3', '5', '2', '6', '4'] is -2.30 ± 0.51 kcal/mol
# DDG for cycle ['3', '5', '2', '6'] is -0.43 ± 0.32 kcal/mol
# DDG for cycle ['3', '5', '2'] is -0.23 ± 0.21 kcal/mol
# DDG for cycle ['3', '2', '6', '7', '4'] is -1.17 ± 0.56 kcal/mol
# DDG for cycle ['3', '2', '6', '7'] is -0.40 ± 0.56 kcal/mol
# DDG for cycle ['3', '2', '6', '4', '7'] is -1.30 ± 0.69 kcal/mol
# DDG for cycle ['3', '2', '6', '4'] is -2.07 ± 0.54 kcal/mol
# DDG for cycle ['3', '2', '6', '5'] is -0.60 ± 0.42 kcal/mol
# DDG for cycle ['3', '2', '6'] is -0.20 ± 0.37 kcal/mol
# DDG for cycle ['3', '2', '5', '6', '7', '4'] is -0.34 ± 0.51 kcal/mol
# DDG for cycle ['3', '2', '5', '6', '7'] is 0.43 ± 0.51 kcal/mol
# DDG for cycle ['3', '2', '5', '6', '4', '7'] is -0.47 ± 0.65 kcal/mol
# DDG for cycle ['3', '2', '5', '6', '4'] is -1.24 ± 0.49 kcal/mol
# DDG for cycle ['3', '2', '5', '6'] is 0.63 ± 0.30 kcal/mol
# DDG for cycle ['3', '2', '5'] is 0.23 ± 0.21 kcal/mol
# DDG for cycle ['2', '6', '5'] is -0.83 ± 0.36 kcal/mol
# DDG for cycle ['2', '5', '6'] is 0.83 ± 0.36 kcal/mol
# DDG for cycle ['4', '6', '7'] is 0.90 ± 0.58 kcal/mol
# DDG for cycle ['4', '7', '6'] is -0.90 ± 0.58 kcal/mol
