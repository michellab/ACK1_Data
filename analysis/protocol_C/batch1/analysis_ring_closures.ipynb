# %%
# %pylab inline
import networkx as nx # does network analysis
matplotlib.rcParams.update({'font.size': 20})
#unimportant
import sys
import scipy.stats
sys.path.append('/Volumes/Edimburgo/ack1/batch0001/analysis/ipython/pose1/dry') #adjust path to where you are working
import helper_scripts_analysis as helper
import seaborn as sns
sns.set_style("ticks")
sns.set_context("notebook", font_scale = 2)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/admin/miniconda3/lib/python2.7/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
#computational data

# %%
sim_data = ['mbar_ring_closure.csv']
comp_graph = nx.read_edgelist(
    sim_data[0], delimiter=',', create_using=nx.DiGraph(),nodetype=str, data=(('weight',float),('error',float)))
comp_graph = helper.symmetrize_graph(comp_graph)
for e in comp_graph.edges():
    print 'Free energy: %s %s %.2f' %(e[0], e[1],comp_graph.get_edge_data(e[0], e[1])['weight'])
pathaverage_comp = helper.get_average_paths(comp_graph, '2')
helper.get_cycles(comp_graph)
# Out:
# -0.9
# 1.0
# -1.4
# -1.9
# 2.0
# 0.0
# -0.67
# -2.2
# -2.6
# 0.6
# 0.4
# Free energy: 3 2 -2.00
# Free energy: 3 5 -0.90
# Free energy: 3 4 1.00
# Free energy: 3 7 -1.40
# Free energy: 3 6 -1.90
# Free energy: 2 3 2.00
# Free energy: 2 5 0.67
# Free energy: 2 6 0.00
# Free energy: 5 3 0.90
# Free energy: 5 2 -0.67
# Free energy: 5 6 -0.60
# Free energy: 4 3 -1.00
# Free energy: 4 7 -2.20
# Free energy: 4 6 -2.60
# Free energy: 7 3 1.40
# Free energy: 7 4 2.20
# Free energy: 7 6 -0.40
# Free energy: 6 3 1.90
# Free energy: 6 2 -0.00
# Free energy: 6 5 0.60
# Free energy: 6 4 2.60
# Free energy: 6 7 0.40
# DDG for path ['2', '3'] is 2.000000 +/- 0.200000 kcal/mol
# DDG for path ['2', '5', '3'] is 1.570000 +/- 0.063246 kcal/mol
# DDG for path ['2', '6', '3'] is 1.900000 +/- 0.223607 kcal/mol
# DDG for path ['2', '5', '6', '3'] is 1.970000 +/- 0.224499 kcal/mol
# DDG for path ['2', '6', '5', '3'] is 1.500000 +/- 0.289137 kcal/mol
# DDG for path ['2', '6', '4', '3'] is 1.600000 +/- 0.300000 kcal/mol
# DDG for path ['2', '6', '7', '3'] is 1.800000 +/- 0.346410 kcal/mol
# DDG for path ['2', '5', '6', '4', '3'] is 1.670000 +/- 0.300666 kcal/mol
# DDG for path ['2', '6', '4', '7', '3'] is 1.800000 +/- 0.360555 kcal/mol
# DDG for path ['2', '6', '7', '4', '3'] is 1.600000 +/- 0.400000 kcal/mol
# DDG for path ['2', '5', '6', '7', '3'] is 1.870000 +/- 0.346987 kcal/mol
# DDG for path ['2', '5', '6', '4', '7', '3'] is 1.870000 +/- 0.361109 kcal/mol
# DDG for path ['2', '5', '6', '7', '4', '3'] is 1.670000 +/- 0.400500 kcal/mol
# Average sum for path to 3 is 1.755385
# ================
# DDG for path ['2'] is 0.000000 +/- 0.000000 kcal/mol
# Average sum for path to 2 is 0.000000
# ================
# DDG for path ['2', '5'] is 0.670000 +/- 0.020000 kcal/mol
# DDG for path ['2', '3', '5'] is 1.100000 +/- 0.208806 kcal/mol
# DDG for path ['2', '6', '5'] is 0.600000 +/- 0.282843 kcal/mol
# DDG for path ['2', '3', '6', '5'] is 0.700000 +/- 0.300000 kcal/mol
# DDG for path ['2', '6', '3', '5'] is 1.000000 +/- 0.231517 kcal/mol
# DDG for path ['2', '3', '4', '6', '5'] is 1.000000 +/- 0.360555 kcal/mol
# DDG for path ['2', '6', '4', '3', '5'] is 0.700000 +/- 0.305941 kcal/mol
# DDG for path ['2', '3', '7', '6', '5'] is 0.800000 +/- 0.400000 kcal/mol
# DDG for path ['2', '6', '7', '3', '5'] is 0.900000 +/- 0.351568 kcal/mol
# DDG for path ['2', '3', '4', '7', '6', '5'] is 1.000000 +/- 0.447214 kcal/mol
# DDG for path ['2', '6', '4', '7', '3', '5'] is 0.900000 +/- 0.365513 kcal/mol
# DDG for path ['2', '3', '7', '4', '6', '5'] is 0.800000 +/- 0.412311 kcal/mol
# DDG for path ['2', '6', '7', '4', '3', '5'] is 0.700000 +/- 0.404475 kcal/mol
# Average sum for path to 5 is 0.836154
# ================
# DDG for path ['2', '3', '4'] is 3.000000 +/- 0.282843 kcal/mol
# DDG for path ['2', '6', '4'] is 2.600000 +/- 0.223607 kcal/mol
# DDG for path ['2', '3', '7', '4'] is 2.800000 +/- 0.346410 kcal/mol
# DDG for path ['2', '5', '3', '4'] is 2.570000 +/- 0.209762 kcal/mol
# DDG for path ['2', '6', '3', '4'] is 2.900000 +/- 0.300000 kcal/mol
# DDG for path ['2', '3', '6', '4'] is 2.700000 +/- 0.244949 kcal/mol
# DDG for path ['2', '5', '6', '4'] is 2.670000 +/- 0.224499 kcal/mol
# DDG for path ['2', '6', '7', '4'] is 2.600000 +/- 0.346410 kcal/mol
# DDG for path ['2', '3', '7', '6', '4'] is 2.800000 +/- 0.360555 kcal/mol
# DDG for path ['2', '5', '3', '7', '4'] is 2.370000 +/- 0.289828 kcal/mol
# DDG for path ['2', '6', '3', '7', '4'] is 2.700000 +/- 0.360555 kcal/mol
# DDG for path ['2', '3', '5', '6', '4'] is 3.100000 +/- 0.305941 kcal/mol
# DDG for path ['2', '3', '6', '7', '4'] is 2.700000 +/- 0.360555 kcal/mol
# DDG for path ['2', '5', '6', '3', '4'] is 2.970000 +/- 0.300666 kcal/mol
# DDG for path ['2', '6', '5', '3', '4'] is 2.500000 +/- 0.351568 kcal/mol
# DDG for path ['2', '6', '7', '3', '4'] is 2.800000 +/- 0.400000 kcal/mol
# DDG for path ['2', '5', '3', '6', '4'] is 2.270000 +/- 0.154919 kcal/mol
# DDG for path ['2', '5', '6', '7', '4'] is 2.670000 +/- 0.346987 kcal/mol
# DDG for path ['2', '5', '3', '7', '6', '4'] is 2.370000 +/- 0.306594 kcal/mol
# DDG for path ['2', '3', '5', '6', '7', '4'] is 3.100000 +/- 0.404475 kcal/mol
# DDG for path ['2', '5', '6', '3', '7', '4'] is 2.770000 +/- 0.361109 kcal/mol
# DDG for path ['2', '6', '5', '3', '7', '4'] is 2.300000 +/- 0.404475 kcal/mol
# DDG for path ['2', '5', '3', '6', '7', '4'] is 2.270000 +/- 0.306594 kcal/mol
# DDG for path ['2', '5', '6', '7', '3', '4'] is 2.870000 +/- 0.400500 kcal/mol
# Average sum for path to 4 is 2.683333
# ================
# DDG for path ['2', '3', '7'] is 0.600000 +/- 0.282843 kcal/mol
# DDG for path ['2', '6', '7'] is 0.400000 +/- 0.282843 kcal/mol
# DDG for path ['2', '3', '4', '7'] is 0.800000 +/- 0.346410 kcal/mol
# DDG for path ['2', '5', '3', '7'] is 0.170000 +/- 0.209762 kcal/mol
# DDG for path ['2', '6', '3', '7'] is 0.500000 +/- 0.300000 kcal/mol
# DDG for path ['2', '3', '6', '7'] is 0.500000 +/- 0.300000 kcal/mol
# DDG for path ['2', '5', '6', '7'] is 0.470000 +/- 0.283549 kcal/mol
# DDG for path ['2', '6', '4', '7'] is 0.400000 +/- 0.300000 kcal/mol
# DDG for path ['2', '3', '4', '6', '7'] is 0.800000 +/- 0.360555 kcal/mol
# DDG for path ['2', '5', '3', '4', '7'] is 0.370000 +/- 0.289828 kcal/mol
# DDG for path ['2', '6', '3', '4', '7'] is 0.700000 +/- 0.360555 kcal/mol
# DDG for path ['2', '3', '5', '6', '7'] is 0.900000 +/- 0.351568 kcal/mol
# DDG for path ['2', '3', '6', '4', '7'] is 0.500000 +/- 0.316228 kcal/mol
# DDG for path ['2', '5', '6', '3', '7'] is 0.570000 +/- 0.300666 kcal/mol
# DDG for path ['2', '6', '5', '3', '7'] is 0.100000 +/- 0.351568 kcal/mol
# DDG for path ['2', '6', '4', '3', '7'] is 0.200000 +/- 0.360555 kcal/mol
# DDG for path ['2', '5', '3', '6', '7'] is 0.070000 +/- 0.232379 kcal/mol
# DDG for path ['2', '5', '6', '4', '7'] is 0.470000 +/- 0.300666 kcal/mol
# DDG for path ['2', '5', '3', '4', '6', '7'] is 0.370000 +/- 0.306594 kcal/mol
# DDG for path ['2', '3', '5', '6', '4', '7'] is 0.900000 +/- 0.365513 kcal/mol
# DDG for path ['2', '5', '6', '3', '4', '7'] is 0.770000 +/- 0.361109 kcal/mol
# DDG for path ['2', '6', '5', '3', '4', '7'] is 0.300000 +/- 0.404475 kcal/mol
# DDG for path ['2', '5', '3', '6', '4', '7'] is 0.070000 +/- 0.252982 kcal/mol
# DDG for path ['2', '5', '6', '4', '3', '7'] is 0.270000 +/- 0.361109 kcal/mol
# Average sum for path to 7 is 0.466667
# ================
# DDG for path ['2', '6'] is 0.000000 +/- 0.200000 kcal/mol
# DDG for path ['2', '3', '6'] is 0.100000 +/- 0.223607 kcal/mol
# DDG for path ['2', '5', '6'] is 0.070000 +/- 0.200998 kcal/mol
# DDG for path ['2', '3', '5', '6'] is 0.500000 +/- 0.289137 kcal/mol
# DDG for path ['2', '5', '3', '6'] is -0.330000 +/- 0.118322 kcal/mol
# DDG for path ['2', '3', '4', '6'] is 0.400000 +/- 0.300000 kcal/mol
# DDG for path ['2', '3', '7', '6'] is 0.200000 +/- 0.346410 kcal/mol
# DDG for path ['2', '5', '3', '4', '6'] is -0.030000 +/- 0.232379 kcal/mol
# DDG for path ['2', '3', '4', '7', '6'] is 0.400000 +/- 0.400000 kcal/mol
# DDG for path ['2', '3', '7', '4', '6'] is 0.200000 +/- 0.360555 kcal/mol
# DDG for path ['2', '5', '3', '7', '6'] is -0.230000 +/- 0.289828 kcal/mol
# DDG for path ['2', '5', '3', '4', '7', '6'] is -0.030000 +/- 0.352136 kcal/mol
# DDG for path ['2', '5', '3', '7', '4', '6'] is -0.230000 +/- 0.306594 kcal/mol
# Average sum for path to 6 is 0.078462
# ================
# DDG for cycle ['3', '6', '7', '4'] is -0.30 ± 0.36 kcal/mol
# DDG for cycle ['3', '6', '7'] is -0.10 ± 0.30 kcal/mol
# DDG for cycle ['3', '6', '4', '7'] is -0.10 ± 0.32 kcal/mol
# DDG for cycle ['3', '6', '4'] is -0.30 ± 0.24 kcal/mol
# DDG for cycle ['3', '6', '5', '2'] is 0.03 ± 0.30 kcal/mol
# DDG for cycle ['3', '6', '5'] is -0.40 ± 0.23 kcal/mol
# DDG for cycle ['3', '6', '2', '5'] is -0.33 ± 0.23 kcal/mol
# DDG for cycle ['3', '6', '2'] is 0.10 ± 0.30 kcal/mol
# DDG for cycle ['3', '7', '6', '4'] is -0.20 ± 0.36 kcal/mol
# DDG for cycle ['3', '7', '6', '5', '2'] is 0.13 ± 0.40 kcal/mol
# DDG for cycle ['3', '7', '6', '5'] is -0.30 ± 0.35 kcal/mol
# DDG for cycle ['3', '7', '6', '2', '5'] is -0.23 ± 0.35 kcal/mol
# DDG for cycle ['3', '7', '6', '2'] is 0.20 ± 0.40 kcal/mol
# DDG for cycle ['3', '7', '6'] is 0.10 ± 0.30 kcal/mol
# DDG for cycle ['3', '7', '4', '6', '5', '2'] is 0.13 ± 0.41 kcal/mol
# DDG for cycle ['3', '7', '4', '6', '5'] is -0.30 ± 0.37 kcal/mol
# DDG for cycle ['3', '7', '4', '6', '2', '5'] is -0.23 ± 0.37 kcal/mol
# DDG for cycle ['3', '7', '4', '6', '2'] is 0.20 ± 0.41 kcal/mol
# DDG for cycle ['3', '7', '4', '6'] is 0.10 ± 0.32 kcal/mol
# DDG for cycle ['3', '7', '4'] is -0.20 ± 0.35 kcal/mol
# DDG for cycle ['3', '4', '6', '7'] is 0.20 ± 0.36 kcal/mol
# DDG for cycle ['3', '4', '6', '5', '2'] is 0.33 ± 0.36 kcal/mol
# DDG for cycle ['3', '4', '6', '5'] is -0.10 ± 0.31 kcal/mol
# DDG for cycle ['3', '4', '6', '2', '5'] is -0.03 ± 0.31 kcal/mol
# DDG for cycle ['3', '4', '6', '2'] is 0.40 ± 0.36 kcal/mol
# DDG for cycle ['3', '4', '6'] is 0.30 ± 0.24 kcal/mol
# DDG for cycle ['3', '4', '7', '6', '5', '2'] is 0.33 ± 0.45 kcal/mol
# DDG for cycle ['3', '4', '7', '6', '5'] is -0.10 ± 0.40 kcal/mol
# DDG for cycle ['3', '4', '7', '6', '2', '5'] is -0.03 ± 0.40 kcal/mol
# DDG for cycle ['3', '4', '7', '6', '2'] is 0.40 ± 0.45 kcal/mol
# DDG for cycle ['3', '4', '7', '6'] is 0.30 ± 0.36 kcal/mol
# DDG for cycle ['3', '4', '7'] is 0.20 ± 0.35 kcal/mol
# DDG for cycle ['3', '5', '6', '7', '4'] is 0.10 ± 0.40 kcal/mol
# DDG for cycle ['3', '5', '6', '7'] is 0.30 ± 0.35 kcal/mol
# DDG for cycle ['3', '5', '6', '4', '7'] is 0.30 ± 0.37 kcal/mol
# DDG for cycle ['3', '5', '6', '4'] is 0.10 ± 0.31 kcal/mol
# DDG for cycle ['3', '5', '6', '2'] is 0.50 ± 0.35 kcal/mol
# DDG for cycle ['3', '5', '6'] is 0.40 ± 0.23 kcal/mol
# DDG for cycle ['3', '5', '2', '6', '7', '4'] is 0.03 ± 0.40 kcal/mol
# DDG for cycle ['3', '5', '2', '6', '7'] is 0.23 ± 0.35 kcal/mol
# DDG for cycle ['3', '5', '2', '6', '4', '7'] is 0.23 ± 0.37 kcal/mol
# DDG for cycle ['3', '5', '2', '6', '4'] is 0.03 ± 0.31 kcal/mol
# DDG for cycle ['3', '5', '2', '6'] is 0.33 ± 0.23 kcal/mol
# DDG for cycle ['3', '5', '2'] is 0.43 ± 0.21 kcal/mol
# DDG for cycle ['3', '2', '6', '7', '4'] is -0.40 ± 0.45 kcal/mol
# DDG for cycle ['3', '2', '6', '7'] is -0.20 ± 0.40 kcal/mol
# DDG for cycle ['3', '2', '6', '4', '7'] is -0.20 ± 0.41 kcal/mol
# DDG for cycle ['3', '2', '6', '4'] is -0.40 ± 0.36 kcal/mol
# DDG for cycle ['3', '2', '6', '5'] is -0.50 ± 0.35 kcal/mol
# DDG for cycle ['3', '2', '6'] is -0.10 ± 0.30 kcal/mol
# DDG for cycle ['3', '2', '5', '6', '7', '4'] is -0.33 ± 0.45 kcal/mol
# DDG for cycle ['3', '2', '5', '6', '7'] is -0.13 ± 0.40 kcal/mol
# DDG for cycle ['3', '2', '5', '6', '4', '7'] is -0.13 ± 0.41 kcal/mol
# DDG for cycle ['3', '2', '5', '6', '4'] is -0.33 ± 0.36 kcal/mol
# DDG for cycle ['3', '2', '5', '6'] is -0.03 ± 0.30 kcal/mol
# DDG for cycle ['3', '2', '5'] is -0.43 ± 0.21 kcal/mol
# DDG for cycle ['2', '6', '5'] is -0.07 ± 0.28 kcal/mol
# DDG for cycle ['2', '5', '6'] is 0.07 ± 0.28 kcal/mol
# DDG for cycle ['4', '6', '7'] is 0.00 ± 0.30 kcal/mol
# DDG for cycle ['4', '7', '6'] is -0.00 ± 0.30 kcal/mol
