# %%
# %pylab inline
import networkx as nx # does network analysis
matplotlib.rcParams.update({'font.size': 20})
#unimportant
import sys
import scipy.stats
sys.path.append('/Volumes/Edimburgo/ack1/batch0001/analysis/ipython/best_poses/wet') #adjust path to where you are working
import helper_scripts_analysis as helper
import seaborn as sns
sns.set_style("ticks")
sns.set_context("notebook", font_scale = 2)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/admin/miniconda3/lib/python2.7/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
#computational data

# %%
sim_data = ['mbar_ring_closure.csv']
comp_graph = nx.read_edgelist(
    sim_data[0], delimiter=',', create_using=nx.DiGraph(),nodetype=str, data=(('weight',float),('error',float)))
comp_graph = helper.symmetrize_graph(comp_graph)
for e in comp_graph.edges():
    print 'Free energy: %s %s %.2f' %(e[0], e[1],comp_graph.get_edge_data(e[0], e[1])['weight'])
pathaverage_comp = helper.get_average_paths(comp_graph, '2')
helper.get_cycles(comp_graph)
# Out:
# -1.2
# 0.5
# -0.5
# -1.4
# 1.0
# 0.2
# -0.5
# -0.3
# -1.4
# 0.3
# 0.0
# Free energy: 3 2 -1.00
# Free energy: 3 5 -1.20
# Free energy: 3 4 0.50
# Free energy: 3 7 -0.50
# Free energy: 3 6 -1.40
# Free energy: 2 3 1.00
# Free energy: 2 5 0.50
# Free energy: 2 6 0.20
# Free energy: 5 3 1.20
# Free energy: 5 2 -0.50
# Free energy: 5 6 -0.30
# Free energy: 4 3 -0.50
# Free energy: 4 7 -0.30
# Free energy: 4 6 -1.40
# Free energy: 7 3 0.50
# Free energy: 7 4 0.30
# Free energy: 7 6 -0.00
# Free energy: 6 3 1.40
# Free energy: 6 2 -0.20
# Free energy: 6 5 0.30
# Free energy: 6 4 1.40
# Free energy: 6 7 0.00
# DDG for path ['2', '3'] is 1.000000 +/- 0.400000 kcal/mol
# DDG for path ['2', '5', '3'] is 1.700000 +/- 0.223607 kcal/mol
# DDG for path ['2', '6', '3'] is 1.600000 +/- 0.223607 kcal/mol
# DDG for path ['2', '5', '6', '3'] is 1.600000 +/- 0.374166 kcal/mol
# DDG for path ['2', '6', '5', '3'] is 1.700000 +/- 0.374166 kcal/mol
# DDG for path ['2', '6', '4', '3'] is 1.100000 +/- 0.458258 kcal/mol
# DDG for path ['2', '6', '7', '3'] is 0.700000 +/- 0.640312 kcal/mol
# DDG for path ['2', '5', '6', '4', '3'] is 1.100000 +/- 0.547723 kcal/mol
# DDG for path ['2', '6', '4', '7', '3'] is 1.800000 +/- 0.754983 kcal/mol
# DDG for path ['2', '6', '7', '4', '3'] is 0.000000 +/- 0.360555 kcal/mol
# DDG for path ['2', '5', '6', '7', '3'] is 0.700000 +/- 0.707107 kcal/mol
# DDG for path ['2', '5', '6', '4', '7', '3'] is 1.800000 +/- 0.812404 kcal/mol
# DDG for path ['2', '5', '6', '7', '4', '3'] is 0.000000 +/- 0.469042 kcal/mol
# Average sum for path to 3 is 1.138462
# ================
# DDG for path ['2'] is 0.000000 +/- 0.000000 kcal/mol
# Average sum for path to 2 is 0.000000
# ================
# DDG for path ['2', '5'] is 0.500000 +/- 0.100000 kcal/mol
# DDG for path ['2', '3', '5'] is -0.200000 +/- 0.447214 kcal/mol
# DDG for path ['2', '6', '5'] is 0.500000 +/- 0.316228 kcal/mol
# DDG for path ['2', '3', '6', '5'] is -0.100000 +/- 0.538516 kcal/mol
# DDG for path ['2', '6', '3', '5'] is 0.400000 +/- 0.300000 kcal/mol
# DDG for path ['2', '3', '4', '6', '5'] is 0.400000 +/- 0.670820 kcal/mol
# DDG for path ['2', '6', '4', '3', '5'] is -0.100000 +/- 0.500000 kcal/mol
# DDG for path ['2', '3', '7', '6', '5'] is 0.800000 +/- 0.806226 kcal/mol
# DDG for path ['2', '6', '7', '3', '5'] is -0.500000 +/- 0.670820 kcal/mol
# DDG for path ['2', '3', '4', '7', '6', '5'] is 1.500000 +/- 0.608276 kcal/mol
# DDG for path ['2', '6', '4', '7', '3', '5'] is 0.600000 +/- 0.781025 kcal/mol
# DDG for path ['2', '3', '7', '4', '6', '5'] is -0.300000 +/- 0.900000 kcal/mol
# DDG for path ['2', '6', '7', '4', '3', '5'] is -1.200000 +/- 0.412311 kcal/mol
# Average sum for path to 5 is 0.176923
# ================
# DDG for path ['2', '3', '4'] is 1.500000 +/- 0.447214 kcal/mol
# DDG for path ['2', '6', '4'] is 1.600000 +/- 0.412311 kcal/mol
# DDG for path ['2', '3', '7', '4'] is 0.800000 +/- 0.748331 kcal/mol
# DDG for path ['2', '5', '3', '4'] is 2.200000 +/- 0.300000 kcal/mol
# DDG for path ['2', '6', '3', '4'] is 2.100000 +/- 0.300000 kcal/mol
# DDG for path ['2', '3', '6', '4'] is 1.000000 +/- 0.600000 kcal/mol
# DDG for path ['2', '5', '6', '4'] is 1.600000 +/- 0.509902 kcal/mol
# DDG for path ['2', '6', '7', '4'] is 0.500000 +/- 0.300000 kcal/mol
# DDG for path ['2', '3', '7', '6', '4'] is 1.900000 +/- 0.848528 kcal/mol
# DDG for path ['2', '5', '3', '7', '4'] is 1.500000 +/- 0.670820 kcal/mol
# DDG for path ['2', '6', '3', '7', '4'] is 1.400000 +/- 0.670820 kcal/mol
# DDG for path ['2', '3', '5', '6', '4'] is 0.900000 +/- 0.670820 kcal/mol
# DDG for path ['2', '3', '6', '7', '4'] is -0.100000 +/- 0.529150 kcal/mol
# DDG for path ['2', '5', '6', '3', '4'] is 2.100000 +/- 0.424264 kcal/mol
# DDG for path ['2', '6', '5', '3', '4'] is 2.200000 +/- 0.424264 kcal/mol
# DDG for path ['2', '6', '7', '3', '4'] is 1.200000 +/- 0.670820 kcal/mol
# DDG for path ['2', '5', '3', '6', '4'] is 1.700000 +/- 0.500000 kcal/mol
# DDG for path ['2', '5', '6', '7', '4'] is 0.500000 +/- 0.424264 kcal/mol
# DDG for path ['2', '5', '3', '7', '6', '4'] is 2.600000 +/- 0.781025 kcal/mol
# DDG for path ['2', '3', '5', '6', '7', '4'] is -0.200000 +/- 0.608276 kcal/mol
# DDG for path ['2', '5', '6', '3', '7', '4'] is 1.400000 +/- 0.734847 kcal/mol
# DDG for path ['2', '6', '5', '3', '7', '4'] is 1.500000 +/- 0.734847 kcal/mol
# DDG for path ['2', '5', '3', '6', '7', '4'] is 0.600000 +/- 0.412311 kcal/mol
# DDG for path ['2', '5', '6', '7', '3', '4'] is 1.200000 +/- 0.734847 kcal/mol
# Average sum for path to 4 is 1.320833
# ================
# DDG for path ['2', '3', '7'] is 0.500000 +/- 0.721110 kcal/mol
# DDG for path ['2', '6', '7'] is 0.200000 +/- 0.223607 kcal/mol
# DDG for path ['2', '3', '4', '7'] is 1.200000 +/- 0.489898 kcal/mol
# DDG for path ['2', '5', '3', '7'] is 1.200000 +/- 0.640312 kcal/mol
# DDG for path ['2', '6', '3', '7'] is 1.100000 +/- 0.640312 kcal/mol
# DDG for path ['2', '3', '6', '7'] is -0.400000 +/- 0.489898 kcal/mol
# DDG for path ['2', '5', '6', '7'] is 0.200000 +/- 0.374166 kcal/mol
# DDG for path ['2', '6', '4', '7'] is 1.300000 +/- 0.458258 kcal/mol
# DDG for path ['2', '3', '4', '6', '7'] is 0.100000 +/- 0.632456 kcal/mol
# DDG for path ['2', '5', '3', '4', '7'] is 1.900000 +/- 0.360555 kcal/mol
# DDG for path ['2', '6', '3', '4', '7'] is 1.800000 +/- 0.360555 kcal/mol
# DDG for path ['2', '3', '5', '6', '7'] is -0.500000 +/- 0.574456 kcal/mol
# DDG for path ['2', '3', '6', '4', '7'] is 0.700000 +/- 0.632456 kcal/mol
# DDG for path ['2', '5', '6', '3', '7'] is 1.100000 +/- 0.707107 kcal/mol
# DDG for path ['2', '6', '5', '3', '7'] is 1.200000 +/- 0.707107 kcal/mol
# DDG for path ['2', '6', '4', '3', '7'] is 0.600000 +/- 0.754983 kcal/mol
# DDG for path ['2', '5', '3', '6', '7'] is 0.300000 +/- 0.360555 kcal/mol
# DDG for path ['2', '5', '6', '4', '7'] is 1.300000 +/- 0.547723 kcal/mol
# DDG for path ['2', '5', '3', '4', '6', '7'] is 0.800000 +/- 0.538516 kcal/mol
# DDG for path ['2', '3', '5', '6', '4', '7'] is 0.600000 +/- 0.700000 kcal/mol
# DDG for path ['2', '5', '6', '3', '4', '7'] is 1.800000 +/- 0.469042 kcal/mol
# DDG for path ['2', '6', '5', '3', '4', '7'] is 1.900000 +/- 0.469042 kcal/mol
# DDG for path ['2', '5', '3', '6', '4', '7'] is 1.400000 +/- 0.538516 kcal/mol
# DDG for path ['2', '5', '6', '4', '3', '7'] is 0.600000 +/- 0.812404 kcal/mol
# Average sum for path to 7 is 0.870833
# ================
# DDG for path ['2', '6'] is 0.200000 +/- 0.100000 kcal/mol
# DDG for path ['2', '3', '6'] is -0.400000 +/- 0.447214 kcal/mol
# DDG for path ['2', '5', '6'] is 0.200000 +/- 0.316228 kcal/mol
# DDG for path ['2', '3', '5', '6'] is -0.500000 +/- 0.538516 kcal/mol
# DDG for path ['2', '5', '3', '6'] is 0.300000 +/- 0.300000 kcal/mol
# DDG for path ['2', '3', '4', '6'] is 0.100000 +/- 0.600000 kcal/mol
# DDG for path ['2', '3', '7', '6'] is 0.500000 +/- 0.748331 kcal/mol
# DDG for path ['2', '5', '3', '4', '6'] is 0.800000 +/- 0.500000 kcal/mol
# DDG for path ['2', '3', '4', '7', '6'] is 1.200000 +/- 0.529150 kcal/mol
# DDG for path ['2', '3', '7', '4', '6'] is -0.600000 +/- 0.848528 kcal/mol
# DDG for path ['2', '5', '3', '7', '6'] is 1.200000 +/- 0.670820 kcal/mol
# DDG for path ['2', '5', '3', '4', '7', '6'] is 1.900000 +/- 0.412311 kcal/mol
# DDG for path ['2', '5', '3', '7', '4', '6'] is 0.100000 +/- 0.781025 kcal/mol
# Average sum for path to 6 is 0.384615
# ================
# DDG for cycle ['3', '6', '7', '4'] is -1.60 ± 0.40 kcal/mol
# DDG for cycle ['3', '6', '7'] is -0.90 ± 0.66 kcal/mol
# DDG for cycle ['3', '6', '4', '7'] is 0.20 ± 0.77 kcal/mol
# DDG for cycle ['3', '6', '4'] is -0.50 ± 0.49 kcal/mol
# DDG for cycle ['3', '6', '5', '2'] is -0.60 ± 0.55 kcal/mol
# DDG for cycle ['3', '6', '5'] is 0.10 ± 0.41 kcal/mol
# DDG for cycle ['3', '6', '2', '5'] is 0.10 ± 0.32 kcal/mol
# DDG for cycle ['3', '6', '2'] is -0.60 ± 0.46 kcal/mol
# DDG for cycle ['3', '7', '6', '4'] is 0.40 ± 0.77 kcal/mol
# DDG for cycle ['3', '7', '6', '5', '2'] is 0.30 ± 0.81 kcal/mol
# DDG for cycle ['3', '7', '6', '5'] is 1.00 ± 0.73 kcal/mol
# DDG for cycle ['3', '7', '6', '2', '5'] is 1.00 ± 0.68 kcal/mol
# DDG for cycle ['3', '7', '6', '2'] is 0.30 ± 0.75 kcal/mol
# DDG for cycle ['3', '7', '6'] is 0.90 ± 0.66 kcal/mol
# DDG for cycle ['3', '7', '4', '6', '5', '2'] is -0.80 ± 0.91 kcal/mol
# DDG for cycle ['3', '7', '4', '6', '5'] is -0.10 ± 0.83 kcal/mol
# DDG for cycle ['3', '7', '4', '6', '2', '5'] is -0.10 ± 0.79 kcal/mol
# DDG for cycle ['3', '7', '4', '6', '2'] is -0.80 ± 0.85 kcal/mol
# DDG for cycle ['3', '7', '4', '6'] is -0.20 ± 0.77 kcal/mol
# DDG for cycle ['3', '7', '4'] is -0.70 ± 0.66 kcal/mol
# DDG for cycle ['3', '4', '6', '7'] is -0.40 ± 0.77 kcal/mol
# DDG for cycle ['3', '4', '6', '5', '2'] is -0.10 ± 0.68 kcal/mol
# DDG for cycle ['3', '4', '6', '5'] is 0.60 ± 0.57 kcal/mol
# DDG for cycle ['3', '4', '6', '2', '5'] is 0.60 ± 0.51 kcal/mol
# DDG for cycle ['3', '4', '6', '2'] is -0.10 ± 0.61 kcal/mol
# DDG for cycle ['3', '4', '6'] is 0.50 ± 0.49 kcal/mol
# DDG for cycle ['3', '4', '7', '6', '5', '2'] is 1.00 ± 0.62 kcal/mol
# DDG for cycle ['3', '4', '7', '6', '5'] is 1.70 ± 0.50 kcal/mol
# DDG for cycle ['3', '4', '7', '6', '2', '5'] is 1.70 ± 0.42 kcal/mol
# DDG for cycle ['3', '4', '7', '6', '2'] is 1.00 ± 0.54 kcal/mol
# DDG for cycle ['3', '4', '7', '6'] is 1.60 ± 0.40 kcal/mol
# DDG for cycle ['3', '4', '7'] is 0.70 ± 0.66 kcal/mol
# DDG for cycle ['3', '5', '6', '7', '4'] is -1.70 ± 0.50 kcal/mol
# DDG for cycle ['3', '5', '6', '7'] is -1.00 ± 0.73 kcal/mol
# DDG for cycle ['3', '5', '6', '4', '7'] is 0.10 ± 0.83 kcal/mol
# DDG for cycle ['3', '5', '6', '4'] is -0.60 ± 0.57 kcal/mol
# DDG for cycle ['3', '5', '6', '2'] is -0.70 ± 0.55 kcal/mol
# DDG for cycle ['3', '5', '6'] is -0.10 ± 0.41 kcal/mol
# DDG for cycle ['3', '5', '2', '6', '7', '4'] is -1.70 ± 0.42 kcal/mol
# DDG for cycle ['3', '5', '2', '6', '7'] is -1.00 ± 0.68 kcal/mol
# DDG for cycle ['3', '5', '2', '6', '4', '7'] is 0.10 ± 0.79 kcal/mol
# DDG for cycle ['3', '5', '2', '6', '4'] is -0.60 ± 0.51 kcal/mol
# DDG for cycle ['3', '5', '2', '6'] is -0.10 ± 0.32 kcal/mol
# DDG for cycle ['3', '5', '2'] is -0.70 ± 0.46 kcal/mol
# DDG for cycle ['3', '2', '6', '7', '4'] is -1.00 ± 0.54 kcal/mol
# DDG for cycle ['3', '2', '6', '7'] is -0.30 ± 0.75 kcal/mol
# DDG for cycle ['3', '2', '6', '4', '7'] is 0.80 ± 0.85 kcal/mol
# DDG for cycle ['3', '2', '6', '4'] is 0.10 ± 0.61 kcal/mol
# DDG for cycle ['3', '2', '6', '5'] is 0.70 ± 0.55 kcal/mol
# DDG for cycle ['3', '2', '6'] is 0.60 ± 0.46 kcal/mol
# DDG for cycle ['3', '2', '5', '6', '7', '4'] is -1.00 ± 0.62 kcal/mol
# DDG for cycle ['3', '2', '5', '6', '7'] is -0.30 ± 0.81 kcal/mol
# DDG for cycle ['3', '2', '5', '6', '4', '7'] is 0.80 ± 0.91 kcal/mol
# DDG for cycle ['3', '2', '5', '6', '4'] is 0.10 ± 0.68 kcal/mol
# DDG for cycle ['3', '2', '5', '6'] is 0.60 ± 0.55 kcal/mol
# DDG for cycle ['3', '2', '5'] is 0.70 ± 0.46 kcal/mol
# DDG for cycle ['2', '6', '5'] is 0.00 ± 0.33 kcal/mol
# DDG for cycle ['2', '5', '6'] is 0.00 ± 0.33 kcal/mol
# DDG for cycle ['4', '6', '7'] is -1.10 ± 0.49 kcal/mol
# DDG for cycle ['4', '7', '6'] is 1.10 ± 0.49 kcal/mol
